# %%
# data manipulation
import numpy as np
import pandas as pd

# data viz
import matplotlib.pyplot as plt

# %%
# mengimport data 
datamin = pd.read_csv("courses.csv")
datamin.head()
# Out:
#         id                                              title  \
# 0   567828  The Complete Python Bootcamp From Zero to Hero...
# 1  1565838         The Complete 2023 Web Development Bootcamp
# 2   625204                    The Web Developer Bootcamp 2023
# 3   756150        Angular - The Complete Guide (2023 Edition)
# 4  2776760  100 Days of Code: The Complete Python Pro Boot...
#
#                                               url    rating  num_reviews  \
# 0               /course/complete-python-bootcamp/  4.592782       452973
# 1  /course/the-complete-web-development-bootcamp/  4.667258       263152
# 2             /course/the-web-developer-bootcamp/  4.696147       254711
# 3        /course/the-complete-guide-to-angular-2/  4.592692       180257
# 4                       /course/100-days-of-code/  4.695252       177568
#
#    num_published_lectures               created last_update_date  \
# 0                     155  2015-07-29T00:12:23Z       2021-03-14
# 1                     490  2018-02-22T12:02:33Z       2023-01-20
# 2                     616  2015-09-28T21:32:19Z       2023-02-12
# 3                     472  2016-02-08T17:02:55Z       2023-02-06
# 4                     676  2020-01-24T10:47:21Z       2022-11-30
#
#            duration  instructors_id  \
# 0    22 total hours         9685726
# 1  65.5 total hours        31334738
# 2    64 total hours         4466306
# 3  34.5 total hours        13952972
# 4    64 total hours        31334738
#
#                                                image
# 0  https://img-c.udemycdn.com/course/750x422/5678...
# 1  https://img-c.udemycdn.com/course/750x422/1565...
# 2  https://img-c.udemycdn.com/course/750x422/6252...
# 3  https://img-c.udemycdn.com/course/750x422/7561...
# 4  https://img-c.udemycdn.com/course/750x422/2776...

# %% [markdown]
# ### EDA (Exploratory Data Analysis)

# %%
x = datamin.iloc[:, 1:4]
x
# Out:
#                                                    title  \
# 0      The Complete Python Bootcamp From Zero to Hero...
# 1             The Complete 2023 Web Development Bootcamp
# 2                        The Web Developer Bootcamp 2023
# 3            Angular - The Complete Guide (2023 Edition)
# 4      100 Days of Code: The Complete Python Pro Boot...
# ...                                                  ...
# 83099  Was sind Subliminales und wie stelle ich sie h...
# 83100  Introduction au Piano populaire (avec symboles...
# 83101                           あい先生のピアノレッスン　親子で学ぶピアノ準備編
# 83102    Spielerisch Gitarre Spielen Lernen Für Anfänger
# 83103                        クロマチックハーモニカをはじめる前に知っておきたいこと
#
#                                                      url    rating
# 0                      /course/complete-python-bootcamp/  4.592782
# 1         /course/the-complete-web-development-bootcamp/  4.667258
# 2                    /course/the-web-developer-bootcamp/  4.696147
# 3               /course/the-complete-guide-to-angular-2/  4.592692
# 4                              /course/100-days-of-code/  4.695252
# ...                                                  ...       ...
# 83099  /course/was-sind-subliminales-und-wie-stelle-i...  1.500000
# 83100  /course/arrangement-pour-piano-i-les-technique...  0.000000
# 83101                                /course/aipiano004/  0.000000
# 83102  /course/spielerisch-gitarre-spielen-lernen-fur...  0.000000
# 83103                        /course/harmonica_beginner/  0.000000
#
# [83104 rows x 3 columns]

# %%
y = datamin.iloc[:, 4:-2]
y
# Out:
#        num_reviews  num_published_lectures               created  \
# 0           452973                     155  2015-07-29T00:12:23Z
# 1           263152                     490  2018-02-22T12:02:33Z
# 2           254711                     616  2015-09-28T21:32:19Z
# 3           180257                     472  2016-02-08T17:02:55Z
# 4           177568                     676  2020-01-24T10:47:21Z
# ...            ...                     ...                   ...
# 83099            1                       5  2022-12-17T12:25:46Z
# 83100            0                      28  2022-05-19T15:10:45Z
# 83101            0                      24  2022-05-02T13:43:00Z
# 83102            0                      13  2022-10-31T06:54:15Z
# 83103            0                       9  2022-02-11T08:12:45Z
#
#       last_update_date          duration
# 0           2021-03-14    22 total hours
# 1           2023-01-20  65.5 total hours
# 2           2023-02-12    64 total hours
# 3           2023-02-06  34.5 total hours
# 4           2022-11-30    64 total hours
# ...                ...               ...
# 83099       2022-12-28      1 total hour
# 83100       2022-08-25   1.5 total hours
# 83101       2022-07-13     39 total mins
# 83102       2022-11-28   1.5 total hours
# 83103       2022-02-11     31 total mins
#
# [83104 rows x 5 columns]

# %%
datamin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83104 entries, 0 to 83103
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      83104 non-null  int64
#  1   title                   83104 non-null  object
#  2   url                     83104 non-null  object
#  3   rating                  83104 non-null  float64
#  4   num_reviews             83104 non-null  int64
#  5   num_published_lectures  83104 non-null  int64
#  6   created                 83104 non-null  object
#  7   last_update_date        83026 non-null  object
#  8   duration                83104 non-null  object
#  9   instructors_id          83104 non-null  int64
#  10  image                   83104 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 7.0+ MB

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough') 
x = np.array(ct.fit_transform(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\LEGION\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\compose\_column_transformer.py:830, in ColumnTransformer._hstack(self, Xs)
#     826 try:
#     827     # since all columns should be numeric before stacking them
#     828     # in a sparse matrix, `check_array` is used for the
#     829     # dtype conversion if necessary.
# --> 830     converted_Xs = [
#     831         check_array(X, accept_sparse=True, force_all_finite=False)
#     832         for X in Xs
#     833     ]
#     834 except ValueError as e:
#
# File c:\Users\LEGION\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\compose\_column_transformer.py:831, in <listcomp>(.0)
#     826 try:
#     827     # since all columns should be numeric before stacking them
#     828     # in a sparse matrix, `check_array` is used for the
#     829     # dtype conversion if necessary.
#     830     converted_Xs = [
# --> 831         check_array(X, accept_sparse=True, force_all_finite=False)
#     832         for X in Xs
#     833     ]
#     834 except ValueError as e:
#
# File c:\Users\LEGION\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#
# File c:\Users\LEGION\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#
# File c:\Users\LEGION\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: '/course/complete-python-bootcamp/'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 4
#       2 from sklearn.compose import ColumnTransformer
#       3 ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
# ----> 4 x = np.array(ct.fit_transform(x))
#
# File c:\Users\LEGION\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\Users\LEGION\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\compose\_column_transformer.py:751, in ColumnTransformer.fit_transform(self, X, y)
#     748 self._validate_output(Xs)
#     749 self._record_output_indices(Xs)
# --> 751 return self._hstack(list(Xs))
#
# File c:\Users\LEGION\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\compose\_column_transformer.py:835, in ColumnTransformer._hstack(self, Xs)
#     830         converted_Xs = [
#     831             check_array(X, accept_sparse=True, force_all_finite=False)
#     832             for X in Xs
#     833         ]
#     834     except ValueError as e:
# --> 835         raise ValueError(
#     836             "For a sparse output, all columns should "
#     837             "be a numeric or convertible to a numeric."
#     838         ) from e
#     840     return sparse.hstack(converted_Xs).tocsr()
#     841 else:
#
# ValueError: For a sparse output, all columns should be a numeric or convertible to a numeric.
